# %%
# Setup()
# Compare_models(): Compare multiples modelos y los ranker 
# Create_model () : Crear un modelo específico
# Tune_models( ):  Ajuste automático del modelo
# Plot_model() : Visualizar el desempeño del modelo
# Evaluate_model() : Evaluación del modelo
# Predict_model() : Predicciones sobre nuevos datos en el Df.
# Save_model/load_model() :

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\leo_2\OneDrive\Documentos\MLEngineer_Especialización\data\precio_departamentos.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area_m2           100 non-null    int64
#  1   num_habitaciones  100 non-null    int64
#  2   num_banos         100 non-null    int64
#  3   distrito          100 non-null    object
#  4   antiguedad_anos   100 non-null    int64
#  5   vista_mar         100 non-null    int64
#  6   precio            100 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 5.6+ KB

# %%
data.nunique().to_dict().items()
# Out:
# dict_items([('area_m2', 75), ('num_habitaciones', 4), ('num_banos', 2), ('distrito', 4), ('antiguedad_anos', 28), ('vista_mar', 2), ('precio', 100)])

# %%
data['antiguedad_anos'].plot(kind =  )
# Out:
# 0      7
# 1      7
# 2     23
# 3     21
# 4     19
#       ..
# 95    10
# 96    27
# 97    14
# 98    15
# 99    21
# Name: antiguedad_anos, Length: 100, dtype: int64
